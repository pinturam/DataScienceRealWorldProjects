# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Q:/Datasets/Covid19_India/population_india_census2011.csv")

# %%
data.head()
# Out:
#    Sno State / Union Territory  Population  Rural population  \
# 0    1           Uttar Pradesh   199812341         155317278
# 1    2             Maharashtra   112374333          61556074
# 2    3                   Bihar   104099452          92341436
# 3    4             West Bengal    91276115          62183113
# 4    5          Madhya Pradesh    72626809          52557404
#
#    Urban population                         Area                  Density  \
# 0          44495063   240,928 km2 (93,023 sq mi)    828/km2 (2,140/sq mi)
# 1          50818259  307,713 km2 (118,809 sq mi)      365/km2 (950/sq mi)
# 2          11758016    94,163 km2 (36,357 sq mi)  1,102/km2 (2,850/sq mi)
# 3          29093002    88,752 km2 (34,267 sq mi)  1,029/km2 (2,670/sq mi)
# 4          20069405  308,245 km2 (119,014 sq mi)      236/km2 (610/sq mi)
#
#    Gender Ratio
# 0           912
# 1           929
# 2           918
# 3           953
# 4           931

# %%
data.tail()
# Out:
#     Sno                   State / Union Territory  Population  \
# 31   32                                Chandigarh     1055450
# 32   33  Dadra and Nagar Haveli and Daman and Diu      585764
# 33   34               Andaman and Nicobar Islands      380581
# 34   35                                    Ladakh      274000
# 35   36                               Lakshadweep       64473
#
#     Rural population  Urban population                       Area  \
# 31             28991           1026459         114 km2 (44 sq mi)
# 32            243510            342254        603 km2 (233 sq mi)
# 33            237093            143488    8,249 km2 (3,185 sq mi)
# 34             43840            230160  96,701 km2 (37,336 sq mi)
# 35             14141             50332          32 km2 (12 sq mi)
#
#                      Density  Gender Ratio
# 31  9,252/km2 (23,960/sq mi)           818
# 32     970/km2 (2,500/sq mi)           711
# 33        46/km2 (120/sq mi)           876
# ...

# %%
data.columns
# Out:
# Index(['Sno', 'State / Union Territory', 'Population', 'Rural population',
#        'Urban population', 'Area', 'Density', 'Gender Ratio'],
#       dtype='object')

# %%
data.describe()
# Out:
#              Sno    Population  Rural population  Urban population  \
# count  36.000000  3.600000e+01      3.600000e+01      3.600000e+01
# mean   18.500000  3.362689e+07      2.315336e+07      1.047353e+07
# std    10.535654  4.305758e+07      3.212429e+07      1.312631e+07
# min     1.000000  6.447300e+04      1.414100e+04      5.033200e+04
# 25%     9.750000  1.439840e+06      5.451570e+05      6.652765e+05
# 50%    18.500000  2.106970e+07      1.278679e+07      5.167890e+06
# 75%    27.250000  5.229275e+07      3.496766e+07      1.604342e+07
# max    36.000000  1.998123e+08      1.553173e+08      5.081826e+07
#
#        Gender Ratio
# count     36.000000
# mean     937.583333
# std       65.544478
# min      711.000000
# 25%      907.750000
# 50%      947.000000
# 75%      976.750000
# max     1084.000000

# %%
data.isnull().sum()
# Out:
# Sno                        0
# State / Union Territory    0
# Population                 0
# Rural population           0
# Urban population           0
# Area                       0
# Density                    0
# Gender Ratio               0
# dtype: int64

# %% [markdown]
# ## Relating the variables with scatterplots

# %%
data.columns
# Out:
# Index(['Sno', 'State / Union Territory', 'Population', 'Rural population',
#        'Urban population', 'Area', 'Density', 'Gender Ratio'],
#       dtype='object')

# %%
sns.relplot(x='Population', y='State / Union Territory', data=data)

# %%
sns.relplot(x='Rural population', y='State / Union Territory', data=data)

# %%
sns.relplot(x='Urban population', y='State / Union Territory', data=data)

# %%
sns.relplot(x='Area', y='State / Union Territory', data=data)

# %%
sns.relplot(x='Density', y='State / Union Territory', data=data)

# %%
sns.relplot(x='Gender Ratio', y='State / Union Territory', data=data)

# %%
sns.pairplot(data)
