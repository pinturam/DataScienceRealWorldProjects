# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Q:/Datasets/Covid19_India/HospitalBedsIndia.csv")

# %%
data.head()
# Out:
#    Sno                   State/UT NumPrimaryHealthCenters_HMIS  \
# 0    1  Andaman & Nicobar Islands                           27
# 1    2             Andhra Pradesh                         1417
# 2    3          Arunachal Pradesh                          122
# 3    4                      Assam                         1007
# 4    5                      Bihar                         2007
#
#    NumCommunityHealthCenters_HMIS  NumSubDistrictHospitals_HMIS  \
# 0                               4                           NaN
# 1                             198                          31.0
# 2                              62                           NaN
# 3                             166                          14.0
# 4                              63                          33.0
#
#    NumDistrictHospitals_HMIS  TotalPublicHealthFacilities_HMIS  \
# 0                          3                                34
# 1                         20                              1666
# ...

# %%
data.columns
# Out:
# Index(['Sno', 'State/UT', 'NumPrimaryHealthCenters_HMIS',
#        'NumCommunityHealthCenters_HMIS', 'NumSubDistrictHospitals_HMIS',
#        'NumDistrictHospitals_HMIS', 'TotalPublicHealthFacilities_HMIS',
#        'NumPublicBeds_HMIS', 'NumRuralHospitals_NHP18', 'NumRuralBeds_NHP18',
#        'NumUrbanHospitals_NHP18', 'NumUrbanBeds_NHP18'],
#       dtype='object')

# %%
data.tail()
# Out:
#     Sno       State/UT NumPrimaryHealthCenters_HMIS  \
# 32   33        Tripura                          114
# 33   34  Uttar Pradesh                         3277
# 34   35    Uttarakhand                          275
# 35   36    West Bengal                         1374
# 36   37      All India                       29,899
#
#     NumCommunityHealthCenters_HMIS  NumSubDistrictHospitals_HMIS  \
# 32                              22                          12.0
# 33                             671                           NaN
# 34                              69                          19.0
# 35                             406                          70.0
# 36                            5568                        1255.0
#
#     NumDistrictHospitals_HMIS  TotalPublicHealthFacilities_HMIS  \
# 32                          9                               157
# 33                        174                              4122
# ...

# %%
data.describe()
# Out:
#              Sno  NumCommunityHealthCenters_HMIS  \
# count  37.000000                       37.000000
# mean   19.000000                      300.972973
# std    10.824355                      907.160512
# min     1.000000                        2.000000
# 25%    10.000000                       17.000000
# 50%    19.000000                       82.000000
# 75%    28.000000                      229.000000
# max    37.000000                     5568.000000
#
#        NumSubDistrictHospitals_HMIS  NumDistrictHospitals_HMIS  \
# count                     30.000000                  37.000000
# mean                      83.666667                  54.216216
# std                      229.572817                 163.173584
# min                        1.000000                   1.000000
# 25%                        6.000000                   9.000000
# 50%                       25.500000                  23.000000
# 75%                       63.250000                  37.000000
# ...

# %%
data.isnull().sum()
# Out:
# Sno                                 0
# State/UT                            0
# NumPrimaryHealthCenters_HMIS        0
# NumCommunityHealthCenters_HMIS      0
# NumSubDistrictHospitals_HMIS        7
# NumDistrictHospitals_HMIS           0
# TotalPublicHealthFacilities_HMIS    0
# NumPublicBeds_HMIS                  0
# NumRuralHospitals_NHP18             0
# NumRuralBeds_NHP18                  0
# NumUrbanHospitals_NHP18             0
# NumUrbanBeds_NHP18                  0
# dtype: int64

# %% [markdown]
# ## Relating the variables with scatterplots

# %%
data.columns
# Out:
# Index(['Sno', 'State/UT', 'NumPrimaryHealthCenters_HMIS',
#        'NumCommunityHealthCenters_HMIS', 'NumSubDistrictHospitals_HMIS',
#        'NumDistrictHospitals_HMIS', 'TotalPublicHealthFacilities_HMIS',
#        'NumPublicBeds_HMIS', 'NumRuralHospitals_NHP18', 'NumRuralBeds_NHP18',
#        'NumUrbanHospitals_NHP18', 'NumUrbanBeds_NHP18'],
#       dtype='object')

# %%
sns.relplot(x="NumPrimaryHealthCenters_HMIS", y="State/UT", data=data)

# %%
sns.relplot(x="NumCommunityHealthCenters_HMIS", y="State/UT", data=data)

# %%
sns.relplot(x="NumSubDistrictHospitals_HMIS", y="State/UT", data=data)

# %%
sns.relplot(x="NumDistrictHospitals_HMIS", y="State/UT", data=data)

# %%
sns.relplot(x="TotalPublicHealthFacilities_HMIS", y="State/UT", data=data)

# %%
sns.relplot(x="NumPublicBeds_HMIS", y="State/UT", data=data)

# %%
sns.relplot(x="NumRuralHospitals_NHP18", y="State/UT", data=data)

# %%
sns.relplot(x="NumRuralBeds_NHP18", y="State/UT", data=data)

# %%
sns.relplot(x="NumUrbanHospitals_NHP18", y="State/UT", data=data)

# %%
sns.relplot(x="NumUrbanBeds_NHP18", y="State/UT", data=data)

# %%
sns.pairplot(data)

# %%
sns.catplot(x='TotalPublicHealthFacilities_HMIS', y='State/UT', data=data)
